# %% [markdown]
# # Running HDAE for OPOSUM and Restaurant Review Dataset
#
# After running the following code, all the information of evaluation for each epoch will be store in `Results` folder, including `F1 score`, `bar plot`, and `TSNE plot` shown in our paper.

# %%
""" Global Setting """
import os 
from config import get_hparams

# !export PYTHONPATH="./"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# BOOTS, BAGS_AND_CASES, TV, KEYBOARDS, VACUUMS, BLUETOOTH
# "REST_" + "EN" | "SP" | "FR" | "RU" | "DU" | "TU"
DATASET = "REST_EN"
locals().update(get_hparams(DATASET))

sumout = f"./Results/{DATASET}/"
aspect_seeds = f"./data/seedwords/{SEEDS}.{aspects}-weights.txt"
aspect_init_file = f"./data/seedwords/{SEEDS}.{aspects}.txt"
train_type = "rec_mt_neva_tsne"
student_type = "hyper_rec_dis_10_gbl_tsne"

command = f"python3 ./main.py --sumout {sumout} \
                              --aspect_seeds {aspect_seeds} \
                              --aspect_init_file {aspect_init_file} \
                              --general_asp {general_asp} \
                              --dataset {DATASET} \
                              --train_type {train_type} --student_type {student_type} \
                              --lr {lr} \
                              --dis_mu {dis_mu} \
                              --hyper_beta {hyper_beta} \
                              --gb_temp {gb_temp} \
                              --w2v_ratio {w2v_ratio} \
                              --st_num_aspect {st_num_aspect} \
                              --mt_ratio {mt_ratio} \
                              --dis_1 {dis_1} --dis_2 {dis_2} --dis_3 {dis_3} \
                              --aspect_tsne_bt {aspect_tsne_bt}"
# Out:
# dataset =  REST_EN

# %%
""" Running HDAE """
print("Running Command:")
print(' '.join(command.split()))

# !{command}
# Out:
# Running Command:
# python3 ./main.py --sumout ./Results/REST_EN/ --aspect_seeds ./data/seedwords/restaurant.english.30-weights.txt --aspect_init_file ./data/seedwords/restaurant.english.30.txt --general_asp 0 --dataset REST_EN --train_type rec_mt_neva_tsne --student_type hyper_rec_dis_10_gbl_tsne --lr 0.005 --dis_mu 2 --hyper_beta 0.02 --gb_temp 1e-08 --w2v_ratio 0.08 --st_num_aspect 12 --mt_ratio 100 --dis_1 15.0 --dis_2 20.0 --dis_3 50.0 --aspect_tsne_bt 20
# Now GPU: GeForce GTX 1080 Ti
# loading dataset...
# dataset_size: 35
# loading model...
# Epoch: 0
# 100%|███████████████████████████████████████████| 35/35 [00:03<00:00,  9.83it/s]
# epoch: 0, f1_mid: 0.503, prev_best: 0.000
# Epoch: 1
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.69it/s]
# epoch: 1, f1_mid: 0.521, prev_best: 0.503
# Epoch: 2
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 16.01it/s]
# epoch: 2, f1_mid: 0.537, prev_best: 0.521
# Epoch: 3
# 100%|███████████████████████████████████████████| 35/35 [00:04<00:00,  7.63it/s]
# epoch: 3, f1_mid: 0.525, prev_best: 0.537
# Epoch: 4
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 13.90it/s]
# epoch: 4, f1_mid: 0.506, prev_best: 0.537
# Epoch: 5
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 14.77it/s]
# epoch: 5, f1_mid: 0.550, prev_best: 0.537
# Epoch: 6
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.89it/s]
# epoch: 6, f1_mid: 0.492, prev_best: 0.550
# Epoch: 7
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 12.26it/s]
# epoch: 7, f1_mid: 0.542, prev_best: 0.550
# Epoch: 8
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.28it/s]
# epoch: 8, f1_mid: 0.499, prev_best: 0.550
# Epoch: 9
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 14.51it/s]
# epoch: 9, f1_mid: 0.530, prev_best: 0.550
# Epoch: 10
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 14.24it/s]
# epoch: 10, f1_mid: 0.555, prev_best: 0.550
# Epoch: 11
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.99it/s]
# epoch: 11, f1_mid: 0.533, prev_best: 0.555
# Epoch: 12
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.59it/s]
# epoch: 12, f1_mid: 0.543, prev_best: 0.555
# Epoch: 13
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.63it/s]
# epoch: 13, f1_mid: 0.549, prev_best: 0.555
# Epoch: 14
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.25it/s]
# epoch: 14, f1_mid: 0.538, prev_best: 0.555
# Epoch: 15
# 100%|███████████████████████████████████████████| 35/35 [00:02<00:00, 15.24it/s]
# epoch: 15, f1_mid: 0.533, prev_best: 0.555

# %%
""" Show Results """
from PIL import Image

best_epoch = 1 # manually select

display(Image.open(f"{sumout}plot_fig{best_epoch}.png").resize((800, 600)))
display(Image.open(f"{sumout}TSNE_type_fig{best_epoch}.png").resize((800, 600)))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x600 at 0x7FB8D82D9EB0>
# <PIL.Image.Image image mode=RGBA size=800x600 at 0x7FB8D806D070>
