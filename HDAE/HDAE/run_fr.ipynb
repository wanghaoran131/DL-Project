# %% [markdown]
# # Running HDAE for OPOSUM and Restaurant Review Dataset
#
# After running the following code, all the information of evaluation for each epoch will be store in `Results` folder, including `F1 score`, `bar plot`, and `TSNE plot` shown in our paper.

# %%
""" Global Setting """
import os 
from config import get_hparams

# !export PYTHONPATH="./"
os.environ["CUDA_VISIBLE_DEVICES"]="0"


# BOOTS, BAGS_AND_CASES, TV, KEYBOARDS, VACUUMS, BLUETOOTH
# "REST_" + "EN" | "SP" | "FR" | "RU" | "DU" | "TU"
DATASET = "REST_FR"
locals().update(get_hparams(DATASET))

sumout = f"./Results/{DATASET}/"
aspect_seeds = f"./data/seedwords/{SEEDS}.{aspects}-weights.txt"
aspect_init_file = f"./data/seedwords/{SEEDS}.{aspects}.txt"
train_type = "rec_mt_neva_tsne"
student_type = "hyper_rec_dis_10_gbl_tsne"

command = f"python3 ./main.py --sumout {sumout} \
                              --aspect_seeds {aspect_seeds} \
                              --aspect_init_file {aspect_init_file} \
                              --general_asp {general_asp} \
                              --dataset {DATASET} \
                              --train_type {train_type} --student_type {student_type} \
                              --lr {lr} \
                              --dis_mu {dis_mu} \
                              --hyper_beta {hyper_beta} \
                              --gb_temp {gb_temp} \
                              --w2v_ratio {w2v_ratio} \
                              --st_num_aspect {st_num_aspect} \
                              --mt_ratio {mt_ratio} \
                              --dis_1 {dis_1} --dis_2 {dis_2} --dis_3 {dis_3} \
                              --aspect_tsne_bt {aspect_tsne_bt}"
# Out:
# dataset =  REST_FR

# %%
""" Running HDAE """
print("Running Command:")
print(' '.join(command.split()))

# !{command}
# Out:
# Running Command:
# python3 ./main.py --sumout ./Results/REST_FR/ --aspect_seeds ./data/seedwords/restaurant.french.30-weights.txt --aspect_init_file ./data/seedwords/restaurant.french.30.txt --general_asp 0 --dataset REST_FR --train_type rec_mt_neva_tsne --student_type hyper_rec_dis_10_gbl_tsne --lr 0.005 --dis_mu 2 --hyper_beta 0.02 --gb_temp 1e-08 --w2v_ratio 0.08 --st_num_aspect 12 --mt_ratio 100 --dis_1 15.0 --dis_2 20.0 --dis_3 50.0 --aspect_tsne_bt 20
# Now GPU: GeForce GTX 1080 Ti
# loading dataset...
# dataset_size: 31
# loading model...
# Epoch: 0
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 14.91it/s]
# epoch: 0, f1_mid: 0.376, prev_best: 0.000
# Epoch: 1
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 15.43it/s]
# epoch: 1, f1_mid: 0.431, prev_best: 0.376
# Epoch: 2
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 14.54it/s]
# epoch: 2, f1_mid: 0.435, prev_best: 0.431
# Epoch: 3
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 14.44it/s]
# epoch: 3, f1_mid: 0.483, prev_best: 0.435
# Epoch: 4
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 14.35it/s]
# epoch: 4, f1_mid: 0.471, prev_best: 0.483
# Epoch: 5
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 13.24it/s]
# epoch: 5, f1_mid: 0.486, prev_best: 0.483
# Epoch: 6
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 12.44it/s]
# epoch: 6, f1_mid: 0.498, prev_best: 0.486
# Epoch: 7
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 12.78it/s]
# epoch: 7, f1_mid: 0.486, prev_best: 0.498
# Epoch: 8
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 12.01it/s]
# epoch: 8, f1_mid: 0.500, prev_best: 0.498
# Epoch: 9
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 12.00it/s]
# epoch: 9, f1_mid: 0.510, prev_best: 0.500
# Epoch: 10
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 15.47it/s]
# epoch: 10, f1_mid: 0.517, prev_best: 0.510
# Epoch: 11
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.59it/s]
# epoch: 11, f1_mid: 0.498, prev_best: 0.517
# Epoch: 12
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.58it/s]
# epoch: 12, f1_mid: 0.497, prev_best: 0.517
# Epoch: 13
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.87it/s]
# epoch: 13, f1_mid: 0.498, prev_best: 0.517
# Epoch: 14
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 16.06it/s]
# epoch: 14, f1_mid: 0.509, prev_best: 0.517
# Epoch: 15
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.64it/s]
# epoch: 15, f1_mid: 0.524, prev_best: 0.517
# Epoch: 16
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.84it/s]
# epoch: 16, f1_mid: 0.509, prev_best: 0.524
# Epoch: 17
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.60it/s]
# epoch: 17, f1_mid: 0.515, prev_best: 0.524
# Epoch: 18
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.52it/s]
# epoch: 18, f1_mid: 0.471, prev_best: 0.524
# Epoch: 19
# 100%|███████████████████████████████████████████| 31/31 [00:01<00:00, 15.79it/s]
# epoch: 19, f1_mid: 0.447, prev_best: 0.524
# Epoch: 20
# 100%|███████████████████████████████████████████| 31/31 [00:02<00:00, 14.83it/s]
# epoch: 20, f1_mid: 0.473, prev_best: 0.524

# %%
""" Show Results """
from PIL import Image

best_epoch = 1 # manually select

display(Image.open(f"{sumout}plot_fig{best_epoch}.png").resize((800, 600)))
display(Image.open(f"{sumout}TSNE_type_fig{best_epoch}.png").resize((800, 600)))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x600 at 0x7F49609D7FA0>
# <PIL.Image.Image image mode=RGBA size=800x600 at 0x7F4960407BE0>
